# %% [markdown]
# # Robot Manipulation with MoveIt 2
#
# Learn pick-and-place operations.
#
# ## Learning Objectives
# 1. MoveIt 2 architecture
# 2. Grasp pose generation
# 3. Inverse kinematics
# 4. Pick-and-place primitives

# %%
import sys
sys.path.append('../scripts')

from manipulation_primitives import ManipulationPrimitives, GraspPose
import numpy as np

# %% [markdown]
# ## Part 1: Grasp Poses
#
# GraspPose(position, orientation)

# %%
grasp = GraspPose(position=(0.5, 0.0, 0.2))
print(f'Grasp: {grasp.position}')

# %% [markdown]
# ## Exercise
# Generate top-down grasp for a cup at (0.3, 0.4, 0.1).
