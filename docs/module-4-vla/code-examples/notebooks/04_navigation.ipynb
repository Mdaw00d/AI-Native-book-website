# %% [markdown]
# # ROS 2 Navigation with Nav2
#
# Learn autonomous navigation using the Nav2 stack.
#
# ## Learning Objectives
# 1. Nav2 architecture and action servers
# 2. Goal pose publishing
# 3. Path planning and obstacle avoidance
# 4. Feedback monitoring

# %%
import sys
sys.path.append('../scripts')

from navigation_client import NavigationClient, NavigationGoal
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Part 1: Navigation Goals
#
# NavigationGoal(x, y, z, orientation_w)

# %%
goal = NavigationGoal(x=2.0, y=3.0, z=0.0)
print(f'Goal: ({goal.x}, {goal.y})')

# %% [markdown]
# ## Exercise
# Create navigation goals for kitchen, living room, bedroom.
